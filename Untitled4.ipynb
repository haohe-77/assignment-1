# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# --- 1. Specify the correct file path ---
# Based on your previous input, the file path is assumed to be:
# 'C:\Users\卡卡\Desktop\airline-passengers.csv'
# IMPORTANT: If your actual file name is 'airline-passengers.csv.docx',
# Pandas read_csv cannot directly read it. You would need to rename it to .csv
# or use a different library (like python-docx) to read Word documents.
# The 'r' prefix before the string indicates a raw string, which is good practice for Windows paths.
file_path = r'C:\Users\卡卡\Desktop\airline-passengers.csv'

# --- 2. Check if the file exists before attempting to read ---
if not os.path.exists(file_path):
    print(f"Error: File not found at '{file_path}'.")
    print("Please verify:")
    print("1. The filename is indeed 'airline-passengers.csv' (not '.docx').")
    print("2. The file is located in the 'C:\\Users\\卡卡\\Desktop\\' directory.")
else:
    try:
        # --- 3. Read the CSV file using pandas ---
        # usecols=[1] specifies that only the second column (index 1) should be read.
        # engine='python' can sometimes help with parsing complex CSVs, but is often not necessary.
        dataset = pd.read_csv(file_path, usecols=[1], engine='python')

        # --- 4. Improve plotting ---
        # Plot the data from the first (and only) column of the DataFrame.
        # dataset.iloc[:, 0] selects all rows (:) and the first column (0).
        plt.plot(dataset.iloc[:, 0])

        # Add a title and labels for better readability
        plt.title('Airline Passengers Data (Second Column)')
        plt.xlabel('Index') # The x-axis represents the index of the data points
        plt.ylabel('Values from Second Column') # The y-axis represents the values from the second column

        # Display the plot
        plt.show()

    except FileNotFoundError:
        # This exception should ideally not be reached due to the os.path.exists check,
        # but it's good practice to include it.
        print(f"Error: File '{file_path}' was not found during read operation.")
    except IndexError:
        # This error occurs if the CSV file has fewer than 2 columns.
        print(f"Error: The file '{file_path}' does not contain a column at index 1 (the second column).")
        print("Please check the content of your CSV file to ensure it has at least two columns.")
    except Exception as e:
        # Catch any other potential errors during file reading or plotting
        print(f"An error occurred during file reading or plotting: {e}")
# Out:
# Error: File not found at 'C:\Users\卡卡\Desktop\airline-passengers.csv'.
# Please verify:
# 1. The filename is indeed 'airline-passengers.csv' (not '.docx').
# 2. The file is located in the 'C:\Users\卡卡\Desktop\' directory.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install python-docx pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = r'C:\Users\卡卡\Desktop\airline-passengers.csv.txt'

df = pd.read_csv(file_path)
df['Month'] = pd.to_datetime(df['Month'])
df.set_index('Month', inplace=True)

df_scaled = df * 2
"Month","Passengers"
"1949-01",112
"1949-02",118
"1949-03",132
"1949-04",129
"1949-05",121
"1949-06",135
"1949-07",148
"1949-08",148
"1949-09",136
"1949-10",119
"1949-11",104
"1949-12",118
"1950-01",115
"1950-02",126
"1950-03",141
"1950-04",135
"1950-05",125
"1950-06",149
"1950-07",170
"1950-08",170
"1950-09",158
"1950-10",133
"1950-11",114
"1950-12",140
"1951-01",145
"1951-02",150
"1951-03",178
"1951-04",163
"1951-05",172
"1951-06",178
"1951-07",199
"1951-08",199
"1951-09",184
"1951-10",162
"1951-11",146
"1951-12",166
"1952-01",171
"1952-02",180
"1952-03",193
"1952-04",181
"1952-05",183
"1952-06",218
"1952-07",230
"1952-08",242
"1952-09",209
"1952-10",191
"1952-11",172
"1952-12",194
"1953-01",196
"1953-02",196
"1953-03",236
"1953-04",235
"1953-05",229
"1953-06",243
"1953-07",264
"1953-08",272
"1953-09",237
"1953-10",211
"1953-11",180
"1953-12",201
"1954-01",204
"1954-02",188
"1954-03",235
"1954-04",227
"1954-05",234
"1954-06",264
"1954-07",302
"1954-08",293
"1954-09",259
"1954-10",229
"1954-11",203
"1954-12",229
"1955-01",242
"1955-02",233
"1955-03",267
"1955-04",269
"1955-05",270
"1955-06",315
"1955-07",364
"1955-08",347
"1955-09",312
"1955-10",274
"1955-11",237
"1955-12",278
"1956-01",284
"1956-02",277
"1956-03",317
"1956-04",313
"1956-05",318
"1956-06",374
"1956-07",413
"1956-08",405
"1956-09",355
"1956-10",306
"1956-11",271
"1956-12",306
"1957-01",315
"1957-02",301
"1957-03",356
"1957-04",348
"1957-05",355
"1957-06",422
"1957-07",465
"1957-08",467
"1957-09",404
"1957-10",347
"1957-11",305
"1957-12",336
"1958-01",340
"1958-02",318
"1958-03",362
"1958-04",348
"1958-05",363
"1958-06",435
"1958-07",491
"1958-08",505
"1958-09",404
"1958-10",359
"1958-11",310
"1958-12",337
"1959-01",360
"1959-02",342
"1959-03",406
"1959-04",396
"1959-05",420
"1959-06",472
"1959-07",548
"1959-08",559
"1959-09",463
"1959-10",407
"1959-11",362
"1959-12",405
"1960-01",417
"1960-02",391
"1960-03",419
"1960-04",461
"1960-05",472
"1960-06",535
"1960-07",622
"1960-08",606
"1960-09",508
"1960-10",461
"1960-11",390
"1960-12",432

plt.figure(figsize=(10,5))
plt.plot(df_scaled.index, df_scaled['Passengers'])
plt.title("Airline Passengers (Scaled x2)")
plt.xlabel("Month")
plt.ylabel("Passengers")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
pip install scipy tensorflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
tf.random.set_seed(7)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os


file_name = 'airline-passengers.csv.txt'
file_path = os.path.join(r'C:\Users\卡卡\Desktop', file_name)
if not os.path.exists(file_path):
    print(f"Error: File not found at '{file_path}'.")
    print("Please verify:")
    print(f"1. The filename is exactly '{file_name}'.")
    print("2. The file is located in the 'C:\\Users\\卡卡\\Desktop\\' directory.")
else:
    print(f"Attempting to read file: {file_path}")
    try:
        dataframe = pd.read_csv(file_path, usecols=[1], engine='python', encoding='utf-8')
        dataset = dataframe.values
        dataset = dataset.astype('float32')

        print("File read and type conversion successful!")
        print("Dataset preview (first 5 rows):")
        print(dataset[:5])
        if len(dataframe.columns) >= 2:
            plt.figure(figsize=(10, 6))
            plt.plot(dataset[:, 0], dataset[:, 1], marker='o', linestyle='-')

            
            x_label = dataframe.columns[0] if len(dataframe.columns) > 0 else 'Index'
            y_label = dataframe.columns[1] if len(dataframe.columns) > 1 else 'Values'

            plt.title(f'Plot of {y_label} vs {x_label}')
            plt.xlabel(x_label)
            plt.ylabel(y_label)
            plt.grid(True)
            plt.show()

        elif len(dataframe.columns) == 1:
            # If there's only one column, plot that column's data (X-axis will be the index)
            plt.figure(figsize=(10, 6))
            plt.plot(dataset[:, 0], marker='o', linestyle='-')
            plt.title(f'Data from Column: {dataframe.columns[0]}')
            plt.xlabel('Index')
            plt.ylabel(dataframe.columns[0])
            plt.grid(True)
            plt.show()

        else:
            print("Error: Not enough data columns in the file to create a plot.")

    except FileNotFoundError:
        print(f"Error: File '{file_path}' was not found during the read operation.")
    except IndexError:
        print(f"Error: The file '{file_path}' does not contain a column at index 1 (the second column).")
        print("Please check the content of your CSV file to ensure it has at least two columns.")
    except ValueError as ve:
        print(f"Error: Could not convert data to float32. The second column might contain non-numeric values.")
        print(f"Specific error: {ve}")
        print("Please check the file content to ensure the second column contains only numbers.")
    except pd.errors.ParserError as pe:
        print(f"Error: Pandas encountered an error parsing the file. The file format might be incorrect or the delimiter is wrong.")
        print(f"Specific error: {pe}")
        print("Please check the file's delimiter. If it's not a comma, specify the correct delimiter using the `sep` parameter in `pd.read_csv()`, e.g., `sep=';'` or `sep='\\t'`.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
# Out:
# Attempting to read file: C:\Users\卡卡\Desktop\airline-passengers.csv.txt
# File read and type conversion successful!
# Dataset preview (first 5 rows):
# [[112.]
#  [118.]
#  [132.]
#  [129.]
#  [121.]]

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# %%
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(len(train), len(test))
# Out:
# 96 48

# %%
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
look_back = 1

trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# %%
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# D:\python\python3.10.4\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 94/94 - 2s - 23ms/step - loss: 0.0433
# Epoch 2/100
# 94/94 - 0s - 2ms/step - loss: 0.0214
# Epoch 3/100
# 94/94 - 0s - 3ms/step - loss: 0.0158
# Epoch 4/100
# 94/94 - 0s - 2ms/step - loss: 0.0144
# Epoch 5/100
# 94/94 - 0s - 2ms/step - loss: 0.0133
# Epoch 6/100
# 94/94 - 0s - 2ms/step - loss: 0.0123
# Epoch 7/100
# 94/94 - 0s - 2ms/step - loss: 0.0113
# Epoch 8/100
# 94/94 - 0s - 2ms/step - loss: 0.0102
# Epoch 9/100
# 94/94 - 0s - 2ms/step - loss: 0.0092
# Epoch 10/100
# ...

# %%
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

trainScore = np.sqrt(mean_squared_error(trainY[0], trainPredict[:, 0]))
print('Train Score: %.2f RMSE' % (trainScore))

testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:, 0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Train Score: 0.04 RMSE
# Test Score: 0.10 RMSE

# %%
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict) + look_back, :] = trainPredict

testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict) + (look_back * 2) + 1:len(dataset) - 1, :] = testPredict

plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i + look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
tf.random.set_seed(7)

import pandas as pd

file_path = r'C:\Users\卡卡\Desktop\airline-passengers.csv.txt'

dataframe = pd.read_csv(file_path, usecols=[1], engine='python')
dataframe = dataframe * 2

dataset = dataframe.values
dataset = dataset.astype('float32')

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# %%
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size, :], dataset[train_size:len(dataset), :]
print(len(train), len(test))
# Out:
# 96 48

# %%
look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# %%
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
# Out:
# Epoch 1/100
# D:\python\python3.10.4\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 92/92 - 1s - 16ms/step - loss: 0.0586
# Epoch 2/100
# 92/92 - 0s - 2ms/step - loss: 0.0312
# Epoch 3/100
# 92/92 - 0s - 2ms/step - loss: 0.0197
# Epoch 4/100
# 92/92 - 0s - 3ms/step - loss: 0.0161
# Epoch 5/100
# 92/92 - 0s - 2ms/step - loss: 0.0145
# Epoch 6/100
# 92/92 - 0s - 2ms/step - loss: 0.0133
# Epoch 7/100
# 92/92 - 0s - 2ms/step - loss: 0.0121
# Epoch 8/100
# 92/92 - 0s - 2ms/step - loss: 0.0109
# Epoch 9/100
# 92/92 - 0s - 2ms/step - loss: 0.0097
# Epoch 10/100
# 92/92 - 0s - 2ms/step - loss: 0.0086
# Epoch 11/100
# 92/92 - 0s - 2ms/step - loss: 0.0075
# Epoch 12/100
# 92/92 - 0s - 2ms/step - loss: 0.0066
# Epoch 13/100
# 92/92 - 0s - 2ms/step - loss: 0.0058
# Epoch 14/100
# ...

# %%
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %%
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict) + look_back, :] = trainPredict

testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict) + (look_back * 2) + 1:len(dataset) - 1, :] = testPredict

plt.figure(figsize=(10, 5))
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i + look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
tf.random.set_seed(7)

file_path = r'C:\Users\卡卡\Desktop\airline-passengers.csv.txt'

dataframe = pd.read_csv(file_path, usecols=[1], engine='python')
dataframe = dataframe * 2

dataset = dataframe.values
dataset = dataset.astype('float32')

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# %%
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size

train, test = dataset[0:train_size, :], dataset[train_size:len(dataset), :]

print(len(train), len(test))
# Out:
# 96 48

# %%
look_back = 3

trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# %%
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/100
# D:\python\python3.10.4\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 92/92 - 2s - 20ms/step - loss: 0.0693
# Epoch 2/100
# 92/92 - 0s - 2ms/step - loss: 0.0303
# Epoch 3/100
# 92/92 - 0s - 3ms/step - loss: 0.0186
# Epoch 4/100
# 92/92 - 0s - 2ms/step - loss: 0.0154
# Epoch 5/100
# 92/92 - 0s - 3ms/step - loss: 0.0134
# Epoch 6/100
# 92/92 - 0s - 2ms/step - loss: 0.0117
# Epoch 7/100
# 92/92 - 0s - 3ms/step - loss: 0.0102
# Epoch 8/100
# 92/92 - 0s - 3ms/step - loss: 0.0087
# Epoch 9/100
# 92/92 - 0s - 3ms/step - loss: 0.0075
# Epoch 10/100
# ...

# %%
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])

testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step

# %%
trainScore = np.sqrt(mean_squared_error(trainY[0], trainPredict[:, 0]))
print('Train Score: %.2f RMSE' % (trainScore))

testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:, 0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 45.25 RMSE
# Test Score: 94.02 RMSE

# %%
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict) + look_back, :] = trainPredict

testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict) + (look_back * 2) + 1:len(dataset) - 1, :] = testPredict

plt.figure(figsize=(10, 5))
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i + look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

tf.random.set_seed(7)

file_path = r'C:\Users\卡卡\Desktop\airline-passengers.csv.txt'

dataframe = pd.read_csv(file_path, usecols=[1], engine='python')
dataframe = dataframe * 2

dataset = dataframe.values
dataset = dataset.astype('float32')

scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size, :], dataset[train_size:len(dataset), :]

look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))

model = Sequential()
model.add(LSTM(4, input_shape=(look_back, 1)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)

trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

trainScore = np.sqrt(mean_squared_error(trainY[0], trainPredict[:, 0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:, 0]))
print('Test Score: %.2f RMSE' % (testScore))

trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict) + look_back, :] = trainPredict

testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict) + (look_back * 2) + 1:len(dataset) - 1, :] = testPredict

plt.figure(figsize=(10, 5))
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# Epoch 1/100
# D:\python\python3.10.4\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 92/92 - 2s - 18ms/step - loss: 0.0361
# Epoch 2/100
# 92/92 - 0s - 3ms/step - loss: 0.0144
# Epoch 3/100
# 92/92 - 0s - 3ms/step - loss: 0.0121
# Epoch 4/100
# 92/92 - 0s - 3ms/step - loss: 0.0104
# Epoch 5/100
# 92/92 - 0s - 3ms/step - loss: 0.0089
# Epoch 6/100
# 92/92 - 0s - 2ms/step - loss: 0.0076
# Epoch 7/100
# 92/92 - 0s - 2ms/step - loss: 0.0066
# Epoch 8/100
# 92/92 - 0s - 2ms/step - loss: 0.0057
# Epoch 9/100
# 92/92 - 0s - 3ms/step - loss: 0.0051
# Epoch 10/100
# 92/92 - 0s - 3ms/step - loss: 0.0047
# Epoch 11/100
# 92/92 - 0s - 3ms/step - loss: 0.0045
# Epoch 12/100
# 92/92 - 0s - 3ms/step - loss: 0.0043
# Epoch 13/100
# 92/92 - 0s - 2ms/step - loss: 0.0042
# Epoch 14/100
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM, Input
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i + look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

tf.random.set_seed(7)

file_path = r'C:\Users\卡卡\Desktop\airline-passengers.csv.txt'

dataframe = pd.read_csv(file_path, usecols=[1], engine='python')
dataframe = dataframe * 2

dataset = dataframe.values.astype('float32')

scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

train_size = int(len(dataset) * 0.67)
train, test = dataset[0:train_size, :], dataset[train_size:, :]

look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

batch_size = 1

trainX = np.reshape(trainX, (trainX.shape[0], look_back, 1))
testX = np.reshape(testX, (testX.shape[0], look_back, 1))

model = Sequential()
model.add(Input(batch_shape=(batch_size, look_back, 1)))
model.add(LSTM(4, stateful=True, name='stateful_lstm'))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

lstm_layer = model.get_layer('stateful_lstm')

for i in range(100):
    model.fit(trainX, trainY, epochs=1, batch_size=batch_size, verbose=2, shuffle=False)
    lstm_layer.reset_states()

trainPredict = model.predict(trainX, batch_size=batch_size)
testPredict = model.predict(testX, batch_size=batch_size)

trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

trainScore = np.sqrt(mean_squared_error(trainY[0], trainPredict[:, 0]))
print('Train Score: %.2f RMSE' % trainScore)

testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:, 0]))
print('Test Score: %.2f RMSE' % testScore)

trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict) + look_back, :] = trainPredict

testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict) + (look_back * 2) + 1:len(dataset) - 1, :] = testPredict

plt.figure(figsize=(10, 5))
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# 92/92 - 2s - 17ms/step - loss: 0.0060
# 92/92 - 0s - 3ms/step - loss: 0.0171
# 92/92 - 0s - 2ms/step - loss: 0.0098
# 92/92 - 0s - 3ms/step - loss: 0.0070
# 92/92 - 0s - 4ms/step - loss: 0.0054
# 92/92 - 0s - 3ms/step - loss: 0.0047
# 92/92 - 0s - 3ms/step - loss: 0.0044
# 92/92 - 0s - 3ms/step - loss: 0.0043
# 92/92 - 0s - 3ms/step - loss: 0.0042
# 92/92 - 0s - 3ms/step - loss: 0.0042
# 92/92 - 0s - 3ms/step - loss: 0.0042
# 92/92 - 0s - 3ms/step - loss: 0.0042
# 92/92 - 0s - 3ms/step - loss: 0.0041
# 92/92 - 0s - 4ms/step - loss: 0.0041
# 92/92 - 0s - 4ms/step - loss: 0.0041
# 92/92 - 0s - 3ms/step - loss: 0.0041
# 92/92 - 0s - 3ms/step - loss: 0.0041
# 92/92 - 0s - 3ms/step - loss: 0.0041
# 92/92 - 0s - 3ms/step - loss: 0.0040
# 92/92 - 0s - 3ms/step - loss: 0.0040
# 92/92 - 0s - 3ms/step - loss: 0.0040
# 92/92 - 0s - 3ms/step - loss: 0.0040
# 92/92 - 0s - 3ms/step - loss: 0.0040
# 92/92 - 0s - 3ms/step - loss: 0.0039
# 92/92 - 0s - 3ms/step - loss: 0.0039
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM, Input
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i + look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

tf.random.set_seed(7)

file_path = r'C:\Users\卡卡\Desktop\airline-passengers.csv.txt'

dataframe = pd.read_csv(file_path, usecols=[1], engine='python')
dataframe = dataframe * 2

dataset = dataframe.values.astype('float32')

scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

train_size = int(len(dataset) * 0.67)
train, test = dataset[0:train_size, :], dataset[train_size:, :]

look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

batch_size = 1

trainX = np.reshape(trainX, (trainX.shape[0], look_back, 1))
testX = np.reshape(testX, (testX.shape[0], look_back, 1))

model = Sequential()
model.add(Input(batch_shape=(batch_size, look_back, 1)))
model.add(LSTM(4, stateful=True, return_sequences=True, name='lstm_1'))
model.add(LSTM(4, stateful=True, name='lstm_2'))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

lstm_1 = model.get_layer('lstm_1')
lstm_2 = model.get_layer('lstm_2')

for i in range(100):
    model.fit(trainX, trainY, epochs=1, batch_size=batch_size, verbose=2, shuffle=False)
    lstm_1.reset_states()
    lstm_2.reset_states()

trainPredict = model.predict(trainX, batch_size=batch_size)
testPredict = model.predict(testX, batch_size=batch_size)

trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

trainScore = np.sqrt(mean_squared_error(trainY[0], trainPredict[:, 0]))
print('Train Score: %.2f RMSE' % trainScore)

testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:, 0]))
print('Test Score: %.2f RMSE' % testScore)

trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict) + look_back, :] = trainPredict

testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict) + (look_back * 2) + 1:len(dataset) - 1, :] = testPredict

plt.figure(figsize=(10, 5))
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# 92/92 - 3s - 38ms/step - loss: 0.0078
# 92/92 - 0s - 3ms/step - loss: 0.0325
# 92/92 - 0s - 3ms/step - loss: 0.0165
# 92/92 - 0s - 3ms/step - loss: 0.0096
# 92/92 - 0s - 3ms/step - loss: 0.0063
# 92/92 - 0s - 4ms/step - loss: 0.0058
# 92/92 - 0s - 3ms/step - loss: 0.0058
# 92/92 - 0s - 3ms/step - loss: 0.0057
# 92/92 - 0s - 4ms/step - loss: 0.0057
# 92/92 - 0s - 4ms/step - loss: 0.0057
# 92/92 - 0s - 4ms/step - loss: 0.0056
# 92/92 - 0s - 4ms/step - loss: 0.0056
# 92/92 - 1s - 6ms/step - loss: 0.0056
# 92/92 - 0s - 4ms/step - loss: 0.0055
# 92/92 - 0s - 4ms/step - loss: 0.0055
# 92/92 - 0s - 3ms/step - loss: 0.0055
# 92/92 - 0s - 3ms/step - loss: 0.0054
# 92/92 - 0s - 4ms/step - loss: 0.0054
# 92/92 - 0s - 5ms/step - loss: 0.0054
# 92/92 - 0s - 4ms/step - loss: 0.0054
# 92/92 - 0s - 4ms/step - loss: 0.0053
# 92/92 - 0s - 4ms/step - loss: 0.0053
# 92/92 - 0s - 4ms/step - loss: 0.0053
# 92/92 - 0s - 4ms/step - loss: 0.0052
# 92/92 - 0s - 4ms/step - loss: 0.0052
# ...
